# %% [markdown]
# <a href="https://colab.research.google.com/github/Saurav-kumar077/Machine_Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Key Data Structures In Pandas**
# 1- series
# 2- Dataframe 2D
#
# > Add blockquote

# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df=pd.DataFrame({"Names":["Saurav","Gaurav","Rohan","Aman"],"Marks":[100,56,57,98]})
df
# Out:
#     Names  Marks
# 0  Saurav    100
# 1  Gaurav     56
# 2   Rohan     57
# 3    Aman     98

# %%
df = pd.read_csv("iris.txt")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# **Data** **Selection**

# %%
df[["sepal_length","sepal_width"]]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df2 = pd.read_csv("data.txt")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length petal_width species
# 0           5.1          3.5           1.4         0.2  setosa
# 1           4.9          3.0           1.2      setosa     NaN
# 2           0.2          1.3           0.2      setosa     NaN
# 3           4.6          3.1           1.5      setosa     NaN
# 4           5.0          3.6           1.4         0.2  setosa

# %%
df2.dropna()
# Out:
#      sepal_length  sepal_width  petal_length petal_width    species
# 0             5.1          3.5           1.4         0.2     setosa
# 4             5.0          3.6           1.4         0.2     setosa
# 5             5.4          3.9           1.7         0.4     setosa
# 6             4.6          3.4           1.4         0.3     setosa
# 7             5.0          3.4           1.5         0.2     setosa
# ..            ...          ...           ...         ...        ...
# 145           6.7          3.0           5.2         2.3  virginica
# 146           6.3          2.5           5.0         1.9  virginica
# 147           6.5          3.0           5.2           2  virginica
# 148           6.2          3.4           5.4         2.3  virginica
# 149           5.9          3.0           5.1         1.8  virginica
#
# [147 rows x 5 columns]

# %%
df2.fillna(0)
# Out:
#      sepal_length  sepal_width  petal_length petal_width    species
# 0             5.1          3.5           1.4         0.2     setosa
# 1             4.9          3.0           1.2      setosa          0
# 2             0.2          1.3           0.2      setosa          0
# 3             4.6          3.1           1.5      setosa          0
# 4             5.0          3.6           1.4         0.2     setosa
# ..            ...          ...           ...         ...        ...
# 145           6.7          3.0           5.2         2.3  virginica
# 146           6.3          2.5           5.0         1.9  virginica
# 147           6.5          3.0           5.2           2  virginica
# 148           6.2          3.4           5.4         2.3  virginica
# 149           5.9          3.0           5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.rename(columns={"sepal_length":"SL"})
# Out:
#       SL  sepal_width  petal_length petal_width    species
# 0    5.1          3.5           1.4         0.2     setosa
# 1    4.9          3.0           1.2      setosa        NaN
# 2    0.2          1.3           0.2      setosa        NaN
# 3    4.6          3.1           1.5      setosa        NaN
# 4    5.0          3.6           1.4         0.2     setosa
# ..   ...          ...           ...         ...        ...
# 145  6.7          3.0           5.2         2.3  virginica
# 146  6.3          2.5           5.0         1.9  virginica
# 147  6.5          3.0           5.2           2  virginica
# 148  6.2          3.4           5.4         2.3  virginica
# 149  5.9          3.0           5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.rename(columns={"sepal_width":"SW"})
# Out:
#      sepal_length   SW  petal_length petal_width    species
# 0             5.1  3.5           1.4         0.2     setosa
# 1             4.9  3.0           1.2      setosa        NaN
# 2             0.2  1.3           0.2      setosa        NaN
# 3             4.6  3.1           1.5      setosa        NaN
# 4             5.0  3.6           1.4         0.2     setosa
# ..            ...  ...           ...         ...        ...
# 145           6.7  3.0           5.2         2.3  virginica
# 146           6.3  2.5           5.0         1.9  virginica
# 147           6.5  3.0           5.2           2  virginica
# 148           6.2  3.4           5.4         2.3  virginica
# 149           5.9  3.0           5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
len(df)
# Out:
# 150

# %%
df["Zeros"]=[0 for i in range(len(df))]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length petal_width species  Zeros
# 0           5.1          3.5           1.4         0.2  setosa      0
# 1           4.9          3.0           1.2      setosa     NaN      0
# 2           0.2          1.3           0.2      setosa     NaN      0
# 3           4.6          3.1           1.5      setosa     NaN      0
# 4           5.0          3.6           1.4         0.2  setosa      0
